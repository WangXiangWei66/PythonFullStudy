# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
fish=plt.imread('./fish.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 fish=plt.imread('./fish.png')
#
# File D:\venv\Lib\site-packages\matplotlib\pyplot.py:2607, in imread(fname, format)
#    2603 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2604 def imread(
#    2605         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2606 ) -> np.ndarray:
# -> 2607     return matplotlib.image.imread(fname, format)
#
# File D:\venv\Lib\site-packages\matplotlib\image.py:1512, in imread(fname, format)
#    1505 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1506     # Pillow doesn't handle URLs directly.
#    1507     raise ValueError(
#    1508         "Please open the URL for reading and pass the "
#    1509         "result to Pillow, e.g. with "
# ...

# %%
fish

# %%
plt.imshow(fish)

# %%
plt.imshow(fish[::-1])
plt.axis('off')

# %%
plt.imshow(fish[:,::-1])
plt.axis('off')

# %%
plt.imshow(fish[:,:,::-1])
plt.axis('off')

# %%
fish.shape

# %%
fish[::4,::4].shape

# %%
plt.imshow(fish[::4,::4])

# %%
plt.imshow(fish)

# %%
plt.imshow(fish[55:93,75:115])

# %%
fish[55:93,75:115]=np.random.rand(93-55,115-75,3)
plt.imshow(fish)

# %%
import pandas as pd

# %%
from pandas import Series

# %%
l=[1,2,3,4]

# %%
s=Series(l)
s

# %%
s.values

# %%
s.index

# %%
list('abcd')

# %%
l=[1,1,2,3,3,4,6,6,8]
m=set(l)

# %%
m

# %%
list(m)

# %%
s.index=list('abcd')

# %%
s

# %%
s['b']

# %%
s['b']=22

# %%
s

# %%
l

# %%
n=np.array([1,2,3,4])
n

# %%
s2=Series(n)
s2

# %%
s2[0]=11

# %%
s2

# %%
n

# %%
s3=Series(data={'a':1,'b':2,'c':3,'d':4})
s3

# %% [markdown]
# practice

# %%
s1=Series({'语文':150,'数学':150,'英语':150,'理综':300})
s1

# %%
data=[150]*3+[300]
index={'语文','数学','英语','理综'}
s1=Series(data=data,index=index)
s1

# %%
s1

# %%
s1['语文']

# %%
s1.loc['语文']

# %%
s1['语文':'数学']

# %%
s1.loc['语文':'数学']

# %%
s2

# %%
s2.index=[1,2,3,4]

# %%
s2

# %%
s2[0]

# %%
s2.iloc[0]

# %%
s1[0]

# %%
s1.iloc[0]

# %%
s1.index[0]

# %%
s1[0:2]

# %%
s1.iloc[0:2]

# %%
s1

# %%
s1.loc['数学']

# %%
s1.loc[['数学']]

# %%
s1.loc[['数学','数学','语文','英语']]

# %%
s1.iloc[1]

# %%
s1.iloc[[1,0,1,0,2]]

# %%
s1.loc['语文':'英语']

# %%
s1.iloc[0:3]

# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series

# %%
s=Series(data=np.random.randint(0,150,size=(5,)),index=list('abcde'))

# %%
s

# %%
s.shape?

# %%
s.size?

# %%
s.index

# %%
s.values

# %%
s=Series(data=np.random.randint(0,150,size=(10,)),index=list('abcdefghij'))

# %%
s

# %%
s.head()

# %%
s.tail()

# %%
s.tail(15)

# %%
s=Series(data=[1,2,3,None],index=list('abcd'))

# %%
s

# %%
s.loc['d']

# %%
s=Series(data=[1,2,3,np.nan],index=list('abcd'))

# %%
s

# %%
s.loc['d']

# %%
s

# %%
pd.isnull(s)

# %%
pd.notnull(s)

# %%
s

# %%
s.isnull()

# %%
s.notnull()

# %%
s=Series(data=[1,2,3,np.nan],index=list('abcd'),name='s')

# %%
s

# %%
s

# %%
s.name='series'
s

# %%
s

# %%
s+1

# %%
s1=Series(data=[1,2,3,4],index=list('abcd'),name='s1')
s2=Series(data=[4,5,6,7],index=list('cdef'),name='s2')
display(s1,s2)

# %%
s1+s2

# %%
s1.add(s2,fill_value=0)

# %%
s1=Series(data=[126,110,132,256],index=['语文','数学','英语','理综'])
s2=Series(data=[115,130,135,267],index=['语文','数学','英语','文综'])
display(s1,s2)

# %%
s1+s2

# %%
s1.add(s2,fill_value=0)

# %%
s1.add(s2,fill_value=0)/2

# %%
from pandas import DataFrame

# %%
df=DataFrame(data={'语文':np.random.randint(0,150,size=(5,)),
                   '数学':np.random.randint(0,150,size=(5,)),
                   '英语':np.random.randint(0,150,size=(5,)),
                   'python':np.random.randint(0,150,size=(5,))},
             index=['张三','李四','王五','赵六','田七'])
df

# %%
data=np.random.randint(0,150,size=(5,4))
columns= ['语文', '数学', '英语', 'python']
index= ['张三', '李四', '王五', '赵六', '田七']
df=DataFrame(data=data,index=index,columns=columns)
df

# %%
df.values

# %%
df.columns

# %%
df.index

# %%
df.shape

# %%
df=DataFrame(data={'张三':[150,150,150,300],
                   '李四':[0,0,0,0]},
             index=['语文', '数学', '英语', '理综'])
df

# %%
data=list([[150,150,150,300],[0,0,0,0]]).T
columns=['张三','李四']
index=['语文','数学','英语','理综']
df=DataFrame(data=data,index=index,columns=columns)

# %%
data=np.random.randint(0,150,size=(5,4))
columns= ['语文', '数学', '英语', 'python']
index= ['张三', '李四', '王五', '赵六', '田七']
df=DataFrame(data=data,index=index,columns=columns)
df

# %%
df['语文']

# %%
df.语文

# %%
df['理综']=np.random.randint(0,300,size=(5,))
df

# %%
df.文综=np.random.randint(0,300,size=(5,))
df

# %%
df

# %%
df.loc['张三']

# %%
df.iloc[0]

# %%
df.iloc[:,0]

# %%
df

# %%
df['数学']['张三']

# %%
df['数学'].loc['张三']

# %%
df.loc['张三','数学']

# %%
df.iloc[0,1]

# %%
df

# %%
df.loc['张三':'王五']

# %%
df.iloc[0:3]

# %%
df['语文':'英语']

# %%
df.loc[:,'语文':'英语']

# %%
df.iloc[:,0:3]

# %%
df

# %%
df.python

# %%
df['python']

# %%
df.iloc[:,3]

# %%
df.loc[:,'python']

# %%
df.loc['李四']

# %%
df

# %%
df.iloc[1]

# %%
df.loc[:,'数学':'python']

# %%
df.iloc[:,1:4]

# %%
df

# %%
df.loc['李四':'赵六']

# %%
df.iloc[1:4]

# %%
df['李四':'赵六']

# %%
df.loc['赵六','python']

# %%
df.loc[['赵六']]

# %%
df[['语文','语文']]

# %%
df.loc[['赵六'],['python']]

# %%
data=np.random.randint(0,150,size=(5,4))
columns = ['语文', '数学', '英语', 'python']
index = ['张三', '李四', '王五', '赵六', '田七']
df1=DataFrame(data=data,index=index,columns=columns)
df1

# %%
data = np.random.randint(0, 150, size=(6, 4))
columns = ['语文', '数学', '英语', 'python']
index = ['张三', '李四', '王五', '赵六', '田七', '孙八']
df2 = DataFrame(data=data, index=index, columns=columns)
df2

# %%
df1+df2

# %%
10/3

# %%
10//3

# %%
10**3

# %%
(df1.add(df2,fill_value=0))/2

# %%
df

# %%
df+10

# %%
 df_mean=(df1.add(df2,fill_value=0))/2

# %%
df_mean.loc['孙八']=df_mean.loc['孙八']*2
df_mean

# %%
sunba=df_mean.loc['孙八']

# %%
sunba

# %%
df_mean

# %%
df_mean+sunba

# %%
ss=Series(data=np.random.randint(0,150,size=(6,)),index=df_mean.index)
ss

# %%
df_mean

# %%
df_mean+ss

# %%
df_mean.add(ss,axis=0)

# %%
data=np.random.randint(0,150,size=(6,4))
columns = ['语文', '数学', '英语', 'python']
index = ['张三', '李四', '王五', '赵六', '田七', '孙八']
ddd=DataFrame(data=data,index=index,columns=columns)
ddd

# %%
data = np.random.randint(0, 150, size=(6, 4))
columns = ['语文', '数学', '英语', 'python']
index = ['张三', '李四', '王五', '赵六', '田七', '孙八']
ddd2 = DataFrame(data=data, index=index, columns=columns)
ddd2

# %%
(ddd+ddd2)/2

# %%
ddd

# %%
ddd.iloc[0,1]=0
ddd

# %%
ddd.loc['张三','数学']=0

# %%
ddd

# %%
ddd.loc['李四']+=100

# %%
ddd

# %%
ddd+10

# %%
type(None)

# %%
None+1

# %%
import numpy as np

# %%
# %timeit np.arange(1e5,dtype='int').sum()

# %%
# %timeit np.arange(1e5,dtype='float').sum()

# %%
# %timeit np.arange(1e5,dtype='object').sum()

# %%
type(np.nan)

# %%
np.nan+1

# %%
np.nansum(np.array([1,2,3,np.nan]))

# %%
import pandas as pd

# %%
from pandas import DataFrame, Series

# %%
data = np.random.randint(0,150,size=(4,4))
index=['张三','李四','王五','赵六']
columns=(['语文', '数学', '英语', 'python'])
df=DataFrame(data=data, index=index, columns=columns)
df

# %%
df.loc['张三', '数学'] = np.nan

# %%
df

# %%
df.loc['王五', '英语'] = None
df

# %%
type(df.loc['张三', '数学'])

# %%
type(df.loc['王五', '英语'])

# %%
df.sum()

# %%
229/3

# %%
df.mean()

# %%
df

# %%
df.isnull()

# %%
df.notnull()

# %%
df.isnull().any(axis=0)

# %%
any()?

# %%
df.isnull().any(axis=1)

# %%
df

# %%
df.drop(index=['张三', '李四'])

# %%
df.drop(columns='语文')

# %%
df

# %%
df.drop(labels='语文',axis=1)

# %%
df

# %%
df.dropna()

# %%
df

# %%
df.dropna(axis=1)

# %%
dfCopy = df.copy()

# %%
df.dropna(inplace=True)
df

# %%
dfCopy

# %%
df = dfCopy.copy()

# %%
df

# %%
df.iloc[0] = np.nan
df

# %%
df.dropna(how='all')

# %%
df.iloc[0,-1] = 108

# %%
df

# %%
df.dropna(how = 'all', subset=['语文', '数学', '英语'])

# %%
df

# %%
df.fillna(value=108)

# %%
dfMean = df.mean()
dfMean

# %%
df

# %%
zhangsan = df.loc['张三']
zhangsan

# %%
dfMean

# %%
zhangsan.fillna(value=dfMean,inplace=True)
zhangsan

# %%
df

# %%
df.fillna(method= 'ffill',axis=1)

# %%
data = np.random.randint(0,150,size=(4,4))
index=['张三','李四','王五','赵六']
columns=['语文','数学','英语','python']
ddd3=DataFrame(data=data,index=index,columns=columns)
ddd3

# %%
ddd3.loc['张三','英语']=None

# %%
ddd3

# %%
ddd3.fillna(method='ffill',axis=1)

# %%
ddd3.fillna(method='bfill',axis=0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
apple = pd.read_csv('./AAPL.csv')

# %%
apple.head()

# %%
apple.info()

# %%
apple.dtypes

# %%
apple['Date'] = pd.to_datetime(apple['Date'])

# %%
apple.head()

# %%
apple.dtypes

# %%
apple.head()

# %%
apple.set_index(keys=['Date'],inplace=True)

# %%
apple.head()

# %%
apple.reset_index(inplace=True)

# %%
apple.head()

# %%
apple.set_index(keys=['Date'],inplace=True)

# %%
apple['Adj Close'].plot(figsize=(10,6))

# %%
apple.tail()

# %%
from pandas import DataFrame,Series

# %%
columns=[['期中', '期中', '期中', '期中', '期末', '期末', '期末', '期末'],['语文', '数学', '英语', '综合', '语文', '数学', '英语', '综合']]
index=[['一班', '一班', '一班', '一班', '一班', '二班', '二班','二班', '二班', '二班'],['张三', '李四', '王五', '赵六', '田七', '孙八', '钱九', '陈十', '赵四', '小明']]
data=np.random.randint(0,150,size=(10,8))
df=DataFrame(index=index, data=data, columns=columns)
df

# %%
index=[['一班', '一班', '一班', '一班', '一班', '二班', '二班','二班', '二班', '二班'],['张三', '李四', '王五', '赵六', '田七', '孙八', '钱九', '陈十', '赵四', '小明']]
data=np.random.randint(0,150,size=(10, ))
s = Series(data=data, index = index)
s

# %%
columns=pd.MultiIndex.from_arrays([['期中', '期中', '期中', '期中', '期末', '期末', '期末', '期末'],['语文', '数学', '英语', '综合', '语文', '数学', '英语', '综合']])
index=pd.MultiIndex.from_arrays([['一班', '一班', '一班', '一班', '一班', '二班', '二班','二班', '二班', '二班'],['张三', '李四', '王五', '赵六', '田七', '孙八', '钱九', '陈十', '赵四', '小明']])
data=np.random.randint(0,150,size=(10,8))
df=DataFrame(data=data, index=index, columns= columns)
df

# %%
columns=pd.MultiIndex.from_tuples((('期中', '语文'), ('期中', '英语'), ('期中', '数学'), ('期中','综合'), ('期末', '语文'), ('期末', '英语'), ('期末', '数学'), ('期末','综合')))
index= [['一班', '一班', '一班', '一班', '一班', '二班', '二班','二班', '二班', '二班'],['张三', '李四', '王五', '赵六', '田七', '孙八', '钱九', '陈十', '赵四', '小明']]
data=np.random.randint(0,150,size=(10,8))
df=DataFrame(index=index, columns=columns,data=data)
df

# %%
columns=pd.MultiIndex.from_product([['期中', '期末'], ['语文', '数学', '英语', '综合']])
index=[['一班', '一班', '一班', '一班', '一班', '二班', '二班','二班', '二班', '二班'], 
         ['张三', '李四', '王五', '赵六', '田七', '孙八', '钱九', '陈十', '赵四', '小明']]
data=data = np.random.randint(0, 150, size=(10, 8))
df = DataFrame(index=index, columns=columns, data=data)
df

# %%
columns=pd.MultiIndex.from_product([['期中', '期末'], ['语文', '数学', '英语', '综合']])
index=[['一班','二班'],['张三','李四']]
data=np.random.randint(0,150,size=(2,8))
df1=DataFrame(data=data,index=index,columns=columns)
df1

# %%
s

# %%
s.loc['一班']

# %%
s.loc[('一班', '张三')]

# %%
s.iloc[0]

# %%
s.loc['一班':'二班']

# %%
s.loc[('一班','张三'):('二班','钱九')]

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from pandas import Series,DataFrame

# %%
columns=pd.MultiIndex.from_tuples((('期中', '语文'), ('期中', '英语'), ('期中', '数学'), ('期中','综合'), ('期末', '语文'), ('期末', '英语'), ('期末', '数学'), ('期末','综合')))
index= [['一班', '一班', '一班', '一班', '一班', '二班', '二班','二班', '二班', '二班'],['张三', '李四', '王五', '赵六', '田七', '孙八', '钱九', '陈十', '赵四', '小明']]
data=np.random.randint(0,150,size=(10,8))
df=DataFrame(index=index, columns=columns,data=data)
df

# %%
columns=pd.MultiIndex.from_tuples([('期中', '语文'), ('期中', '英语'), ('期中', '数学'), ('期中','综合'), ('期末', '语文'), ('期末', '英语')])
index= [['一班', '一班', '一班', '二班','二班', '二班'],['张三', '李四', '王五', '赵六', '田七', '孙八']]
data=np.random.randint(0,150,size=(6,6))
df=DataFrame(index=index, columns=columns,data=data)
df

# %%
df.loc['一班']

# %%
df.loc['张三']

# %%
df.loc[('一班','张三')]

# %%
df.loc[('一班','张三')]

# %%
df

# %%
df.iloc[0]

# %%
df.loc['一班':'二班']

# %%
df.loc[('一班','张三'):('二班','田七')]

# %%
df

# %%
df.iloc[0:5]

# %%
df

# %%
df['期中','语文']

# %%
df[('期中','语文')]

# %%
df

# %%
df.iloc[:,0]

# %%
df['期中':'期末']

# %%
df.iloc[:,1:4]

# %%
df.loc[('一班','张三'),('期中','语文')]

# %%
df.iloc[0,0]

# %%
df

# %%
df.loc[('一班','张三'),('期中','英语')]=np.nan

# %%
df

# %%
df.dtypes

# %%
df

# %%
df.iloc[0,2]=None
df

# %%
df

# %%
df.stack(level=0)

# %%
df.unstack()

# %%
df.unstack(fill_value=0)

# %%
df.unstack(fill_value=0).stack(level=1).stack(level=0).unstack(level=0)

# %%
df

# %%
df.unstack(fill_value=0)

# %%
df.unstack(fill_value=0).stack(level=(0,1),future_stack=True).unstack(level=0)

# %%
df

# %%
df.stack(level=0,future_stack=True).unstack(level=(0,1))

# %%
df

# %%
df

# %%
df.stack(future_stack=True).unstack(level=(0,1))

# %%
df

# %%
ddd=df.loc['一班','期中'].copy()
ddd

# %%
ddd.sum(axis=0)

# %%
ddd.sum(axis=1)

# %%
ddd.sum()

# %%
df

# %%
df.sum(level=0,axis=0)

# %%
df

# %%
d=df.groupby(level=0).sum()
d

# %%
df

# %%
df.groupby(level=0).sum().stack(future_stack=True).groupby(level=0).sum()

# %%
df

# %%
df.groupby(level=0).sum().groupby(level=0,axis=1).sum()

# %%
df

# %%
df.groupby(axis=1,level=1).mean()

# %%
 df.T.groupby(level = 1).mean().T

# %%
df.T.groupby(axis=1,level=1).max()

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
n1 = np.random.randint(0,10,size=(3,3))
n2 = np.random.randint(0, 10, size=(3,3))
display(n1,n2)

# %%
np.concatenate((n1,n2))

# %%
np.vstack((n1,n2))

# %%
np.concatenate((n1,n2),axis=1)

# %%
np.hstack((n1,n2))

# %%
def make_df(index,cols):
    df = DataFrame({col:[col+str(i) for i in index]for col in cols})
    df.index=index
    return df

# %%
make_df([1,2,3,4],list('ABCD'))

# %%
df1 = make_df([1,2,3,4], list('ABCD'))
df2 = make_df([1,2,3,4], list('ABCD'))
display(df1,df2)

# %%
pd.concat((df1,df2))

# %%
pd.concat((df1,df2), axis=1)

# %%
pd.concat((df1,df2), axis=1, ignore_index=True)

# %%
pd.concat((df1,df2), ignore_index=True)

# %%
pd.concat((df1,df2), keys=['df1', 'df2'])

# %%
pd.concat((df1,df2), axis=1, keys=['df1','df2'])

# %%
pd.concat((df1,df2),verify_integrity=False)

# %%
index=['张三', '李四', '赵六','王五']
columns=['语文', '数学','英语','AI']
data = np.random.randint(0,150,size=(4,4))
ddd=DataFrame(index=index, columns=columns, data=data)
ddd

# %%
ddd['计算机'] = np.random.randint(0,150,size=(4))

# %%
ddd

# %%
index=['张三', '李四', '赵六','王五']
columns = ['计算机']
data=np.random.randint(0,150,size=(4,1))
computer=DataFrame(index=index,columns=columns,data=data)
computer

# %%
pd.concat((ddd,computer),axis=1)

# %%
pd.concat((computer,ddd),axis=1)

# %%
ddd

# %%
ddd.insert(2,'计算机2',np.random.randint(0,150,size=(4,1)))
ddd

# %%
ddd

# %%
ddd.loc['王老五'] = np.random.randint(0,150,size=(6,))
ddd

# %%
columns = ['语文', '数学', '计算机2','英语', 'AI','计算机']
index = ['王老五']
data = np.random.randint(0, 150, size=(1, 6))
laowang = DataFrame(index=index, columns=columns, data=data)
laowang

# %%
pd.concat((ddd,laowang))

# %%
df1 = make_df([1, 2, 3, 4], list('ABCD'))
df2 = make_df([2, 3, 4, 5], list('BCDE'))
display(df1, df2)

# %%
pd.concat((df1,df2))

# %%
pd.concat((df1,df2), axis=1)

# %%
pd.concat((df1,df2),axis=1,join='outer')

# %%
pd.concat((df1,df2), axis=1, join='inner')

# %%
index = ['李四', '赵六', '王五']
columns = ['语文', '数学', '英语', 'AI']
data = np.random.randint(0, 150, size=(3, 4))
ddd2 = DataFrame(index=index, columns=columns, data=data)
ddd1 = DataFrame(index=index, columns=columns, data=data)
display(ddd1,ddd2)

# %%
ddd

# %%
pd.concat((ddd1,ddd2),axis=1,keys=['期中','期末'])

# %%
pd.concat((ddd1,ddd2),axis=0,keys=['期中','期末'])

# %%
df1 = DataFrame({'name':['张三','李四','Chales'],'id':[1,2,3],'age':[22,21,25]})

df2 = DataFrame({'sex':['男','男','女'],'id':[2,3,4],'group':['sale','search','service']})
display(df1, df2)

# %%
pd.merge(df1,df2)

# %%
df1 = DataFrame({'name':['张三','李四','Chales'],'id':[1,2,2],'age':[22,21,25]})

df2 = DataFrame({'sex':['男','男','女'],'id':[2,3,4],'group':['sale','search','service']})
display(df1,df2)

# %%
pd.merge(df1,df2)

# %%
df1 = DataFrame({'name':['张三','李四','张三'],'salary':[10000,12000,20000],'age':[22,21,25]})

df2 = DataFrame({'sex':['男','男','女'],'name':['张三','张三','凡凡'],'group':['sale','search','service']})
display(df1, df2)

# %%
pd.merge(df1, df2)

# %%
df1 = DataFrame({'name':['张三','李四','张三'],'salary':[10000,12000,20000],'age':[22,21,25]})

df2 = DataFrame({'age':[21,18,29],'name':['张三','张三','凡凡'],'group':['sale','search','service']})
display(df1, df2)

# %%
df1.merge(df2)

# %%
df1.merge(df2,on='name')

# %%
df1 = DataFrame({'name':['张三','李四','张三'],'salary':[10000,12000,20000],'age':[22,21,25]})

df2 = DataFrame({'年龄':[21,18,29],'名字':['张三','张三','凡凡'],'group':['sale','search','service']})
display(df1, df2)

# %%
pd.merge(df1,df2,left_on='name',right_on='名字')

# %%
pd.merge(df1,df2,left_on='name',right_on='名字').drop(columns=['名字','年龄'])

# %%
df1 = DataFrame({'name':['张三','李四','张三'],'salary':[10000,12000,20000],'age':[22,21,25]})

df2 = DataFrame({'年龄':[21,18,29],'名字':['张三','张三','凡凡'],'group':['sale','search','service']},
                index = [22,21,25])
display(df1,df2)

# %%
pd.merge(df1,df2,left_on='age',right_index=True)

# %%
index=['张三','李四','王老五']
columns=['语文','数学','英语']
data = np.random.randint(0,150,size=(3,3))
ddd=DataFrame(index=index,columns=columns,data=data)
ddd

# %%
index=['张三','找小六']
columns=['语文','数学','英语']
data = np.random.randint(0,150,size=(2,3))
ddd4=DataFrame(index=index,columns=columns,data=data)
ddd4

# %%
pd.concat((ddd,ddd4),axis=0)

# %%
df1 = DataFrame({'name':['张三','李四','张三'],'salary':[10000,12000,20000],'age':[22,21,25]})

df2 = DataFrame({'age':[21,18,29],'名字':['张三','张三','凡凡'],'group':['sale','search','service']})
display(df1, df2)

# %%
pd.merge(df1,df2)

# %%
pd.merge(df1,df2,how='outer')

# %%
pd.merge(df1,df2,how='left')

# %%
pd.merge(df1,df2,how='right')

# %%
#期中
df1 = DataFrame({'name':['张三','李四','张三'],'degree':[120,118,149],'age':[22,21,25]})

#期末考试
df2 = DataFrame({'degree':[99,97,129],'name':['张三','张三','凡凡'],'group':['sale','search','service']})
display(df1, df2)

# %%
pd.merge(df1,df2,on='name',suffixes=['_df1', '_df2'])

# %%
# unique() 去重函数
s = Series(['Tom','Lucy','Tom','dancer','Lucy'])

# %%
s.unique()

# %%
n = np.array([1,2,1,3,2,4,5])
np.unique(n)

# %%
n = DataFrame({'name':['Tom','Lucy','Tom','dancer','Lucy'],'age':[12,13,12,11,15]})
n

# %%
n.dtypes

# %%
n

# %%
n.query("name=='Lucy' & age>14")

# %%
s_abb = pd.read_csv('./state-abbrevs.csv')
s_abb.head()

# %%
s_pop = pd.read_csv('./state-population.csv')
s_pop.head()

# %%
s_ares = pd.read_csv('./state-areas.csv')
s_ares.head()

# %%
d=pd.merge(s_abb,s_pop,left_on='abbreviation',right_on='state/region',how='outer')

# %%
d

# %%
d.drop('abbreviation',axis=1)

# %%
d.isnull()

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# %%
pd.read_csv('./SMSSpamCollection',sep='/,', header=None)

# %%
pd.read_table('./SMSSpamCollection',header=None)

# %%
pd.read_csv('./dataframe.xls')

# %%
# !pip install xlrd -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
pd.read_csv('./dataframe.xls')

# %%
pd.read_excel('./dataframe.xls',sheet_name=1,index_col=[0,1],header=[0,1])

# %%
pd.read_csv('./type-.txt', sep='-',header=None)

# %%
pd.read_csv('./type_comma',header=None)

# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
columns = ['张三', '李四', '王老五']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 3))
ddd = DataFrame(index = index, columns = columns, data = data)
ddd

# %%
columns = ['张三', '赵小六']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 2))
ddd4 = DataFrame(index = index, columns = columns, data = data)
ddd4

# %%
ddd['张三'] = ddd4['张三']

# %%
display(ddd, ddd4)

# %%
ddd = ddd.merge(ddd4)

# %%
ddd

# %%
ddd.index = ddd4.index
ddd

# %%
columns = ['张三', '李四', '王老五']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 3))
ddd = DataFrame(index = index, columns = columns, data = data)

columns = ['张十三', '赵小六']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 2))
ddd4 = DataFrame(index = index, columns = columns, data = data)
ddd4

ddd['张三'] = ddd4['张十三']
display(ddd,ddd4)

# %%
ddd = ddd.merge(ddd4, left_on = '张三', right_on = '张十三')
ddd

# %%
ddd.index = ddd4.index

# %%
ddd

# %%
ddd.drop(columns = '张十三', inplace = True)
ddd

# %%
columns = ['张三', '李四', '王老五']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 3))
ddd = DataFrame(index = index, columns = columns, data = data)

columns = ['张十三', '赵小六']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 2))
ddd4 = DataFrame(index = index, columns = columns, data = data)
ddd4

ddd['张三'] = ddd4['张十三']
display(ddd,ddd4)

# %%
pd.merge(ddd, ddd4, left_on = '张三', right_on = '张十三', how = 'outer')

# %%
ddd = pd.merge(ddd, ddd4, left_on = '张三', right_on = '张十三', how = 'right')

# %%
ddd.index = ddd4.index
ddd

# %%
columns = ['张三', '李四']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 2))
ddd5 = DataFrame(index = index, columns = columns, data = data)

columns = ['张三', '李四']
index = ['语文', '数学', '英语', 'python']
data = np.random.randint(0, 150, size = (4, 2))
ddd6 = DataFrame(index = index, columns = columns, data = data)
ddd5['张三'] = ddd6['张三']
display(ddd5,ddd6)

# %%
pd.merge(ddd5, ddd6, on = '张三', suffixes=['_1', '_2'])

# %% [markdown]
# Homework:American state people data anlysis

# %%
abb = pd.read_csv('./state-abbrevs.csv')
abb.head()

# %%
pop = pd.read_csv('./state-population.csv')
pop.head()

# %%
areas = pd.read_csv('./state-areas.csv')
areas.head()

# %%
abb_pop = abb.merge(pop, left_on = 'abbreviation', right_on = 'state/region', how = 'outer')

# %%
abb_pop

# %%
abb_pop.drop(columns = 'abbreviation', inplace =True)
abb_pop.head()

# %%
abb_pop.isnull().any(axis = 0)

# %%
abb_pop.isnull().any()

# %%
abb_pop.info()

# %%
cond = abb_pop.isnull().any(axis = 1)
cond

# %%
temp = abb_pop.loc[cond].copy()
temp

# %%
temp['state/region'].unique()

# %%
cond = temp['state/region'] == 'PR'
cond

# %%
temp.loc[cond]['state'] = 'Puerto Rico'

# %%
temp.loc[cond]

# %%
temp.loc[cond, 'state'] = 'Puerto Rico'

# %%
temp.loc[cond]

# %%
cond = temp['state/region'] == 'USA'
temp.loc[cond]

# %%
temp.loc[cond,'state'] = 'Unisted State of America'
temp.loc[cond]

# %%
cond = abb_pop.isnull().any(axis=1)
abb_pop.loc[cond] = temp
abb_pop.loc[cond]

# %%
abb_pop.head()

# %%
areas.head()

# %%
abb_pop_area = abb_pop.merge(areas, how = 'outer')
abb_pop_area.head()

# %%
abb_pop_area.isnull().any()

# %%
cond = abb_pop_area.isnull().any(axis=1)
abb_pop_area.loc[cond]

# %%
abb_pop_area.loc[cond,'state'].unique()

# %%
temp = abb_pop_area.loc[cond].copy()
temp

# %%
temp.loc[temp['state'] == 'Puerto Rico']

# %%
temp.loc[temp['state'] == 'United State of America']

# %%
abb_pop_area.dropna(axis = 0,inplace=True)

# %%
abb_pop_area.isnull().any()

# %%
abb_pop_area.head()

# %%
abb_pop_area.dtypes

# %%
result = abb_pop_area.query('ages == "total" & year==2010')

# %%
result.head()

# %%
result.set_index(keys = 'state', inplace=True)
result.head()

# %%
density = result['population'] / result['area (sq. mi)']

# %%
density.sort_values(inplace=True)

# %%
density.tail()

# %%
density.head()

# %%
import pandas as pd

# %%
import sqlite3

# %%
conn = sqlite3.connect('./data.sqlite')
conn

# %%
weather_2017 = pd.read_sql('select * from weather_2017.csv limit 30', conn, index_col='index')
weather_2017.head()

# %%
weather_2017.to_html('./weather_2017.html')

# %%
pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
def make_df(index,cols):
    df = DataFrame({col: [col + str(i) for i in index] for col in cols})
    df.index = index
    return df

# %%
df = make_df([1,2,3,4], list('ABCD'))
df

# %%
df.loc[1] = df.loc[2]
df

# %%
df.duplicated()

# %%
~df.duplicated()

# %%
df.loc[~df.duplicated()]

# %%
df

# %%
df.duplicated(keep = 'last')

# %%
df.drop_duplicates(keep='first')

# %%
df.drop_duplicates(keep = 'last')

# %%
df

# %%
df.loc[1,'D'] = 'D1'
df

# %%
df.duplicated()

# %%
df.duplicated(subset = ['A', 'B', 'C'])

# %%
~df.duplicated(subset = ['A', 'B', 'C'])

# %%
np.logical_not(df.duplicated(subset = ['A', 'B', 'C']))

# %%
index = ['张三', '李四', '王五', '赵六']
columns = ['语文', '数学', '英语', 'AI']
data = np.random.randint(0, 150, size = (4, 4))
df = DataFrame(index = index, columns = columns, data = data)
df

# %%
df.loc['张三', '数学'] = 8
df

# %%
mapping = {8:108, 3:103, 16:116, 32:132}
df.replace(mapping)

# %%
df.iloc[0,0],df.iloc[0,1] = np.nan, np.nan
df

# %%
df.replace({np.nan: 0})

# %%
df

# %%
df.iloc[0,0]=150
df.iloc[1,1] = 150
df

# %%
df

# %%
mapping = {150:0}

# %%
df.replace(mapping)

# %%
df

# %%
df['综合'] = np.random.randint(0, 300, size = (4))

# %%
df

# %%
mapping = {np.nan:100 , 7: 117, 3: 113}
df['python'] = df['AI'].map(mapping)

# %%
df

# %%
df = df.replace({np.nan:100})

# %%
df['python'] = df['python'].map(lambda score :score - 50)

# %%
df

# %%
def convert(score):
    if score >=120:
        return '优秀'
    elif 120> score >=90:
        return '及格'
    else:
        return '不及格'

# %%
df['AI_score'] = df['AI'].map(convert)
df

# %%
df['AI_score2'] = df['AI'].transform(convert)
df

# %%
columns = ['张三', '李四', '王五', '赵六']
index = ['语文', '数学', '英语', 'AI']
data = np.random.randint(0, 150, size = (4, 4))
df = DataFrame(index = index, columns = columns, data = data)
df

# %%
def convert(score):
    if score >=120:
        return 'excellent'
    elif 120> score >=90:
        return 'pass'
    else:
        return 'failed'

# %%
df['ZhangSan_score'] = df['张三'].map(convert)
df

# %%
df['LiSi_score'] = df['李四'].map(convert)
df

# %%
df

# %%
mapping = {'张三': 'Mr Zhang', '李四':'Mr Lee', '王五': 'Mr Wang','赵六':'Mr Six'}
df.rename(columns = mapping)

# %%
df = DataFrame(data = np.random.randn(10000,3))
df

# %%
df.describe()

# %%
df.std()

# %%
cond = (df.abs() >3*df.std()).any(axis = 1)

# %%
cond

# %%
~cond

# %%
df.loc[~cond]

# %%
index = ['张三', '李四', '赵六', '王五']
columns = ['语文', '数学', '英语', 'AI']
data = np.random.randint(0, 150, size=(4, 4))
df = DataFrame(index=index, columns=columns, data=data)
df

# %%
df.take([0,1,2,])

# %%
ddd = np.random.randint(0,4,size = (4,))

# %%
ddd

# %%
df.take(ddd)

# %%
df

# %%
ddd1 = np.random.permutation([0,1,2,3])
ddd1

# %%
df.take(ddd1)

# %%
df

# %%
df.take(np.random.randint(0,4, size = (4,)))

# %%
df.take(np.random.randint(0,4, size = (4,))[:3])

# %%
df = DataFrame({'color':['red','white','red','cyan','cyan','green','white','cyan'],
                'price':np.random.randint(0,8,size = 8),
                'weight':np.random.randint(50,55,size = 8)})
df

# %%
df.groupby(by = 'color')

# %%
df.groupby(by=['color', 'price']).groups

# %%
df.groupby(by = 'color').groups

# %%
df.groupby(by = 'color').mean()[['price']]

# %%
price_mean = df.groupby(by = 'color')[['price']].mean()

# %%
display(df, price_mean)

# %%
pd.merge(df,price_mean, left_on = 'color', right_index = True, suffixes = ['', '_mean'])

# %%
np.random.randint(0,100, size = 10)

# %%
np.random.rand(10)

# %%
ddd = DataFrame({
    'item': ['萝卜', '萝卜', '萝卜', '白菜','白菜', '辣椒', '辣椒', '辣椒', '冬瓜', '冬瓜'],
    'color': ['白', '青', '红', '白', '青', '白', '青', '红', '白', '青'],
    'weight':np.random.randint(0,100,size = 10),
    'price':np.random.rand(10)*10
})
ddd

# %%
ddd.groupby(by = 'color')[['price']].sum()

# %%
weight_sum = ddd.groupby(by = 'item')[['weight']].sum()
weight_sum

# %%
price_mean = ddd.groupby(by = 'item')[['price']].mean()

# %%
price_mean

# %%
ddd = ddd.merge(weight_sum,left_on = 'item', right_index = True,suffixes = ['','_sum'])

# %%
ddd

# %%
ddd = ddd.merge(price_mean,left_on = 'item', right_index = True,suffixes=['', '_mean'])
ddd

# %%
price_mean

# %%
price_mean = price_mean.add_prefix('mean_')

# %%
price_mean

# %%
ddd

# %%
ddd.merge(price_mean, left_on = 'item',right_index = True)

# %%
ddd

# %%
ddd.groupby(by = 'item')[['weight']].transform("sum")

# %%
ddd.groupby(by = 'item')[['weight']].apply("sum")

# %%
s = Series(data = np.random.randint(0,10,size = 10))
s

# %%
s.plot()

# %%
index = ['张三', '李四', '赵六', '王五']
columns = ['语文', '数学', '英语', 'AI']
data = np.random.randint(0,150, size = (4,4))
df = DataFrame(index = index, columns = columns, data = data)
df

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

# %%
df

# %%
df.loc[-1] = np.random.randint(0,150,size=4)

# %%
df

# %%
df.plot(ylim = (-50,150))

# %%
s

# %%
s.plot(kind = 'bar')

# %%
s.plot(kind = 'barh')

# %%
df

# %%
df.plot(kind = 'bar')

# %%
tips = pd.read_csv('./tips.csv')

# %%
tips

# %%
tips.set_index(keys = 'day', inplace = True)
tips

# %%
tips.plot(kind = 'bar')

# %%
tips

# %%
tips.sum(axis=1)

# %%
tips/tips.sum(axis=1)

# %%
tips.divide(tips.sum(axis=1),axis = 'index')

# %%
tips.divide(tips.sum(axis=1),axis = 'index').plot(kind = 'bar')

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
months = {'JAN' : 1, 'FEB' : 2, 'MAR' : 3, 'APR' : 4, 'MAY' : 5, 'JUN' : 6,
          'JUL' : 7, 'AUG' : 8, 'SEP' : 9, 'OCT': 10, 'NOV': 11, 'DEC' : 12}
of_interest = ['Obama, Barack', 'Romney, Mitt', 'Santorum, Rick', 
               'Paul, Ron', 'Gingrich, Newt']
parties = {
  'Bachmann, Michelle': 'Republican',
  'Romney, Mitt': 'Republican',
  'Obama, Barack': 'Democrat',
  "Roemer, Charles E. 'Buddy' III": 'Reform',
  'Pawlenty, Timothy': 'Republican',
  'Johnson, Gary Earl': 'Libertarian',
  'Paul, Ron': 'Republican',
  'Santorum, Rick': 'Republican',
  'Cain, Herman': 'Republican',
  'Gingrich, Newt': 'Republican',
  'McCotter, Thaddeus G': 'Republican',
  'Huntsman, Jon': 'Republican',
  'Perry, Rick': 'Republican'           
 }

# %%
election = pd.read_csv('./usa_election.txt',low_memory = False)

# %%
election.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st contbr_zip        contbr_employer  \
# 0              MOBILE        AL  366010290                RETIRED
# 1              MOBILE        AL  366010290                RETIRED
# 2              LANETT        AL  368633403  INFORMATION REQUESTED
# 3             PIGGOTT        AR  724548253                   NONE
# 4  HOT SPRINGS NATION        AR  719016467                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED              250.0        20-JUN-11          NaN
# ...

# %%
election.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536041 entries, 0 to 536040
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cmte_id            536041 non-null  object
#  1   cand_id            536041 non-null  object
#  2   cand_nm            536041 non-null  object
#  3   contbr_nm          536041 non-null  object
#  4   contbr_city        536026 non-null  object
#  5   contbr_st          536040 non-null  object
#  6   contbr_zip         535973 non-null  object
#  7   contbr_employer    525088 non-null  object
#  8   contbr_occupation  530520 non-null  object
#  9   contb_receipt_amt  536041 non-null  float64
#  10  contb_receipt_dt   536041 non-null  object
#  11  receipt_desc       8479 non-null    object
#  12  memo_cd            49718 non-null   object
#  13  memo_text          52740 non-null   object
#  14  form_tp            536041 non-null  object
# ...

# %%
election['party'] = election['cand_nm'].map(parties)

# %%
election.head(1)
# Out:
#      cmte_id    cand_id             cand_nm        contbr_nm contbr_city  \
# 0  C00410118  P20002978  Bachmann, Michelle  HARVEY, WILLIAM      MOBILE
#
#   contbr_st contbr_zip contbr_employer contbr_occupation  contb_receipt_amt  \
# 0        AL  366010290         RETIRED           RETIRED              250.0
#
#   contb_receipt_dt receipt_desc memo_cd memo_text form_tp  file_num  \
# 0        20-JUN-11          NaN     NaN       NaN   SA17A    736166
#
#         party
# 0  Republican

# %%
np.unique(election['party'])
# Out:
# array(['Democrat', 'Libertarian', 'Reform', 'Republican'], dtype=object)

# %%
election['party'].value_counts()
# Out:
# party
# Democrat       292400
# Republican     237575
# Reform           5364
# Libertarian       702
# Name: count, dtype: int64

# %%
election.groupby(by = 'party')[['contb_receipt_amt']].sum()
# Out:
#              contb_receipt_amt
# party
# Democrat          8.105758e+07
# Libertarian       4.132769e+05
# Reform            3.390338e+05
# Republican        1.192255e+08

# %%
election.groupby(by =[ 'party', 'contb_receipt_dt'])[['contb_receipt_amt']].sum()
# Out:
#                              contb_receipt_amt
# party      contb_receipt_dt
# Democrat   01-AUG-11                 175281.00
#            01-DEC-11                 651532.82
#            01-JAN-12                  58098.80
#            01-JUL-11                 165961.00
#            01-JUN-11                 145459.00
# ...                                        ...
# Republican 31-JAN-12                 869890.41
#            31-JUL-11                  12781.02
#            31-MAR-11                  62475.00
#            31-MAY-11                 301339.80
#            31-OCT-11                 734601.83
#
# [1183 rows x 1 columns]

# %%
election.dtypes
# Out:
# cmte_id               object
# cand_id               object
# cand_nm               object
# contbr_nm             object
# contbr_city           object
# contbr_st             object
# contbr_zip            object
# contbr_employer       object
# contbr_occupation     object
# contb_receipt_amt    float64
# contb_receipt_dt      object
# receipt_desc          object
# memo_cd               object
# memo_text             object
# form_tp               object
# file_num               int64
# party                 object
# dtype: object

# %%
election['contb_receipt_dt'] = pd.to_datetime(election['contb_receipt_dt'])

# %%
election['contb_receipt_dt']

# %%
def convert(datatime):
    day, month, year = datatime.split('-')
    return '20' + year + '-' +str(months[month]) + '-' +day

# %%
convert('31-OCT-11')
# Out:
# '2011-10-31'

# %%
election['contb_receipt_dt'] = election['contb_receipt_dt'].map(convert)

# %%
election['contb_receipt_dt']
# Out:
# 0         2011-6-20
# 1         2011-6-23
# 2         2011-7-05
# 3         2011-8-01
# 4         2011-6-20
#             ...
# 536036    2011-8-31
# 536037    2011-9-30
# 536038    2011-9-29
# 536039    2011-9-30
# 536040    2011-9-29
# Name: contb_receipt_dt, Length: 536041, dtype: object

# %%
election['contb_receipt_dt'] = pd.to_datetime(election['contb_receipt_dt'])

# %%
election.dtypes
# Out:
# cmte_id                      object
# cand_id                      object
# cand_nm                      object
# contbr_nm                    object
# contbr_city                  object
# contbr_st                    object
# contbr_zip                   object
# contbr_employer              object
# contbr_occupation            object
# contb_receipt_amt           float64
# contb_receipt_dt     datetime64[ns]
# receipt_desc                 object
# memo_cd                      object
# memo_text                    object
# form_tp                      object
# file_num                      int64
# party                        object
# dtype: object

# %%
election.sort_values(by = 'contb_receipt_dt', inplace = True)

# %%
temp = election.groupby(by = ['party', 'contb_receipt_dt'])[['contb_receipt_amt']].sum()

# %%
temp.head()
# Out:
#                            contb_receipt_amt
# party    contb_receipt_dt
# Democrat 2011-04-04                640235.12
#          2011-04-05                307641.00
#          2011-04-06                247542.59
#          2011-04-07                252336.00
#          2011-04-08                295452.00

# %%
temp.unstack(level = 0)
# Out:
#                  contb_receipt_amt
# party                     Democrat Libertarian   Reform Republican
# contb_receipt_dt
# 2011-01-01                     NaN         NaN      NaN    8600.00
# 2011-01-03                     NaN         NaN      NaN    4800.00
# 2011-01-04                     NaN         NaN      NaN    5000.00
# 2011-01-12                     NaN         NaN      NaN    4150.00
# 2011-01-13                     NaN         NaN      NaN    4000.00
# ...                            ...         ...      ...        ...
# 2012-01-27               305785.47         NaN  3176.37  368441.82
# 2012-01-28               235492.85         NaN   175.00   82775.80
# 2012-01-29                93177.00         NaN   200.00   75220.02
# 2012-01-30               435921.72         NaN   130.00  255204.80
# 2012-01-31              1418410.31         NaN   150.00  869890.41
#
# [376 rows x 4 columns]

# %%
n = np.array([1,2,3,4,5])

# %%
n
# Out:
# array([1, 2, 3, 4, 5])

# %%
n.cumsum()
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
temp.unstack(level=0).cumsum().plot()
# Out:
# <Axes: xlabel='contb_receipt_dt'>

# %%
temp.unstack(level=0).cumsum()
# Out:
#                  contb_receipt_amt
# party                     Democrat Libertarian     Reform    Republican
# contb_receipt_dt
# 2011-01-01                     NaN         NaN        NaN  8.600000e+03
# 2011-01-03                     NaN         NaN        NaN  1.340000e+04
# 2011-01-04                     NaN         NaN        NaN  1.840000e+04
# 2011-01-12                     NaN         NaN        NaN  2.255000e+04
# 2011-01-13                     NaN         NaN        NaN  2.655000e+04
# ...                            ...         ...        ...           ...
# 2012-01-27             78874576.93         NaN  338378.78  1.179424e+08
# 2012-01-28             79110069.78         NaN  338553.78  1.180252e+08
# 2012-01-29             79203246.78         NaN  338753.78  1.181004e+08
# 2012-01-30             79639168.50         NaN  338883.78  1.183556e+08
# 2012-01-31             81057578.81         NaN  339033.78  1.192255e+08
#
# [376 rows x 4 columns]

# %%
temp.unstack(level = 1)
# Out:
#                  contb_receipt_amt                                   \
# contb_receipt_dt        2011-01-01 2011-01-03 2011-01-04 2011-01-12
# party
# Democrat                       NaN        NaN        NaN        NaN
# Libertarian                    NaN        NaN        NaN        NaN
# Reform                         NaN        NaN        NaN        NaN
# Republican                  8600.0     4800.0     5000.0     4150.0
#
#                                                                          \
# contb_receipt_dt 2011-01-13 2011-01-14 2011-01-15 2011-01-16 2011-01-17
# party
# Democrat                NaN        NaN        NaN        NaN        NaN
# Libertarian             NaN        NaN        NaN        NaN        NaN
# Reform                  NaN        NaN        NaN        NaN        NaN
# Republican           4000.0     6000.0      500.0      750.0      500.0
#
#                              ...                                              \
# ...

# %%
temp.unstack(level = 0, fill_value = 0).stack(future_stack=True)
# Out:
#                               contb_receipt_amt
# contb_receipt_dt party
# 2011-01-01       Democrat                  0.00
#                  Libertarian               0.00
#                  Reform                    0.00
#                  Republican             8600.00
# 2011-01-03       Democrat                  0.00
# ...                                         ...
# 2012-01-30       Republican           255204.80
# 2012-01-31       Democrat            1418410.31
#                  Libertarian               0.00
#                  Reform                  150.00
#                  Republican           869890.41
#
# [1504 rows x 1 columns]

# %%
election.groupby(by = ['cand_nm', 'contbr_occupation'])[['contb_receipt_amt']].sum()
# Out:
#                                                    contb_receipt_amt
# cand_nm            contbr_occupation
# Bachmann, Michelle 100% DISABLED VETERAN                     1869.50
#                    100% DISABLED VIETNAM VETERAN              236.25
#                    A/C AND HEAT                               250.00
#                    ACADEMIC EMPLOYMENT SPECIALIST              25.00
#                    ACCOUNT                                     50.00
# ...                                                              ...
# Santorum, Rick     WRITER EDITOR                              250.00
#                    WRITER/ACCOUNT EXEC                        500.00
#                    WRITER/JOURNALIST                          250.00
#                    WRITER/LAWYER                              300.00
#                    YOUTH MINISTER                             250.00
#
# [40161 rows x 1 columns]

# %%
cond = election.contbr_occupation == 'DISABLED VETERAN'
cond
# Out:
# 478480    False
# 475327    False
# 475328    False
# 478481    False
# 475329    False
#           ...
# 116633    False
# 63165     False
# 116628    False
# 452120    False
# 187969    False
# Name: contbr_occupation, Length: 536041, dtype: bool

# %%
veteran = election.loc[cond]

# %%
veteran.groupby(by = 'cand_nm')[['contb_receipt_amt']].sum()
# Out:
#                 contb_receipt_amt
# cand_nm
# Cain, Herman               300.00
# Obama, Barack             4205.00
# Paul, Ron                 2425.49
# Santorum, Rick             250.00

# %%
veteran.groupby(by = 'cand_nm')[['contb_receipt_amt']].count()
# Out:
#                 contb_receipt_amt
# cand_nm
# Cain, Herman                    3
# Obama, Barack                  32
# Paul, Ron                      22
# Santorum, Rick                  3

# %%
veteran.groupby(by = 'cand_nm')[['contb_receipt_amt']].sum().reset_index()
# Out:
#           cand_nm  contb_receipt_amt
# 0    Cain, Herman             300.00
# 1   Obama, Barack            4205.00
# 2       Paul, Ron            2425.49
# 3  Santorum, Rick             250.00

# %%
election.groupby(by = ['cand_nm', 'contbr_occupation'])[['contb_receipt_amt']].sum()
# Out:
#                                                    contb_receipt_amt
# cand_nm            contbr_occupation
# Bachmann, Michelle 100% DISABLED VETERAN                     1869.50
#                    100% DISABLED VIETNAM VETERAN              236.25
#                    A/C AND HEAT                               250.00
#                    ACADEMIC EMPLOYMENT SPECIALIST              25.00
#                    ACCOUNT                                     50.00
# ...                                                              ...
# Santorum, Rick     WRITER EDITOR                              250.00
#                    WRITER/ACCOUNT EXEC                        500.00
#                    WRITER/JOURNALIST                          250.00
#                    WRITER/LAWYER                              300.00
#                    YOUTH MINISTER                             250.00
#
# [40161 rows x 1 columns]

# %%
election.groupby(by = ['cand_nm', 'contbr_occupation'])[['contb_receipt_amt']].max()
# Out:
#                                                    contb_receipt_amt
# cand_nm            contbr_occupation
# Bachmann, Michelle 100% DISABLED VETERAN                       500.0
#                    100% DISABLED VIETNAM VETERAN               100.0
#                    A/C AND HEAT                                250.0
#                    ACADEMIC EMPLOYMENT SPECIALIST               25.0
#                    ACCOUNT                                      50.0
# ...                                                              ...
# Santorum, Rick     WRITER EDITOR                               100.0
#                    WRITER/ACCOUNT EXEC                         500.0
#                    WRITER/JOURNALIST                           250.0
#                    WRITER/LAWYER                               300.0
#                    YOUTH MINISTER                              250.0
#
# [40161 rows x 1 columns]

# %%
election.groupby(by = ['cand_nm'])[['contb_receipt_amt']].max()
# Out:
#                                 contb_receipt_amt
# cand_nm
# Bachmann, Michelle                        3022.00
# Cain, Herman                             10000.00
# Gingrich, Newt                            5100.00
# Huntsman, Jon                             5000.00
# Johnson, Gary Earl                        2500.00
# McCotter, Thaddeus G                      4000.00
# Obama, Barack                          1944042.43
# Paul, Ron                                 5000.00
# Pawlenty, Timothy                        10000.00
# Perry, Rick                              10000.00
# Roemer, Charles E. 'Buddy' III             200.00
# Romney, Mitt                             12700.00
# Santorum, Rick                            5000.00

# %%
election.query('cand_nm=="Obama, Barack" & contb_receipt_amt==1944042.43')
# Out:
#           cmte_id    cand_id        cand_nm  \
# 176127  C00431445  P80003338  Obama, Barack
#
#                                    contbr_nm contbr_city contbr_st contbr_zip  \
# 176127  OBAMA VICTORY FUND 2012 - UNITEMIZED     CHICAGO        IL      60680
#
#        contbr_employer contbr_occupation  contb_receipt_amt contb_receipt_dt  \
# 176127             NaN               NaN         1944042.43       2011-12-31
#
#        receipt_desc memo_cd memo_text form_tp  file_num     party
# 176127          NaN       X         *    SA18    763233  Democrat

# %%
s = Series(np.array([1,2,2,3,4,5,5,6,8,8]))

# %%
s
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    4
# 5    5
# 6    5
# 7    6
# 8    8
# 9    8
# dtype: int64

# %%
# !pip install scipy -i https://mirrors.aliyun.com/pypi/simple
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# ...
#      ---------------------------------------- 0.0/40.9 MB ? eta -:--:--
#      - -------------------------------------- 1.6/40.9 MB 9.3 MB/s eta 0:00:05
#      --- ------------------------------------ 3.1/40.9 MB 9.7 MB/s eta 0:00:04
#      ---- ----------------------------------- 5.0/40.9 MB 8.9 MB/s eta 0:00:05
#      ------ --------------------------------- 7.1/40.9 MB 9.1 MB/s eta 0:00:04
#      -------- ------------------------------- 8.7/40.9 MB 8.7 MB/s eta 0:00:04
#      --------- ------------------------------ 10.2/40.9 MB 8.5 MB/s eta 0:00:04
#      ----------- ---------------------------- 12.1/40.9 MB 8.7 MB/s eta 0:00:04
#      ------------- -------------------------- 14.2/40.9 MB 8.7 MB/s eta 0:00:04
#      --------------- ------------------------ 16.0/40.9 MB 8.9 MB/s eta 0:00:03
#      ----------------- ---------------------- 17.6/40.9 MB 8.9 MB/s eta 0:00:03
# ...

# %%
s.plot(kind = 'hist', bins = 20, density = True)
s.plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Out:
# <Axes: ylabel='Density'>

# %%
s
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    4
# 5    5
# 6    5
# 7    6
# 8    8
# 9    8
# dtype: int64

# %%
np.histogram(s,bins = 20)
# Out:
# (array([1, 0, 2, 0, 0, 1, 0, 0, 1, 0, 0, 2, 0, 0, 1, 0, 0, 0, 0, 2]),
#  array([1.  , 1.35, 1.7 , 2.05, 2.4 , 2.75, 3.1 , 3.45, 3.8 , 4.15, 4.5 ,
#         4.85, 5.2 , 5.55, 5.9 , 6.25, 6.6 , 6.95, 7.3 , 7.65, 8.  ]))

# %%
0.1/0.35
# Out:
# 0.28571428571428575

# %%
n1 = np.random.normal(loc = 10, scale = 3,size = 1000)
n2 = np.random.normal(loc = 30, scale= 6, size = 1000)
display(n1, n2)
# Out:
# array([13.0084303 ,  8.15596139,  9.50350885,  9.54099209, 11.29043316,
#        15.1221516 ,  4.6625272 ,  9.93819257, 10.77889105, 10.11268177,
#        10.33508679, 10.62993174, 11.48954575, 10.06572792,  7.3448588 ,
#        15.00247203,  9.71534979,  8.1421676 , 16.2309666 ,  7.17160978,
#        12.24655991, 12.46337565,  8.1178004 , 11.20973171, 10.87432212,
#        12.75188967, 11.12120103, 10.32227333, 10.56830179,  5.23804322,
#         9.05825504,  8.95093206, 14.06041177, 14.97298695,  9.17420139,
#         9.57062118,  8.18676174, 12.86739281, 13.62947813,  8.7962037 ,
#         8.76430086,  7.58012068, 13.50138153,  8.63766511, 11.08021544,
#         7.05047513,  6.31776977, 11.90036286,  6.35536778,  5.26328493,
#         8.59095078, 12.81900349, 10.78327498, 11.80324243,  6.06277466,
#         9.43524423, 13.8918013 , 13.60524713,  9.21514116, 10.84071917,
#        11.60695472, 15.73617917,  8.66490975, 13.50960016,  7.64472703,
# ...

# %%
n = np.hstack((n1,n2))

# %%
n
# Out:
# array([13.0084303 ,  8.15596139,  9.50350885, ..., 27.99993664,
#        32.9976661 , 32.32803612], shape=(2000,))

# %%
s = Series(data = n)

# %%
s.plot(kind = 'hist', bins = 200, density = True)
s.plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, num = 10)
y = np.linspace(2,8,num = 10)
plt.scatter(x, y)

# %%
x
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
df = DataFrame({'A':x, 'B':y})
df.plot(x= 'A', y = 'B', kind = 'scatter')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df = DataFrame({'A':np.random.randn(500), 'B':np.random.randn(500), 'C':np.random.randn(500), 'D':np.random.randn(500)})
df
# Out:
#             A         B         C         D
# 0    0.025838 -0.255804  0.048797 -0.510612
# 1   -1.608035  1.210573  0.128090 -1.587393
# 2    0.372100  0.305164 -0.166593  0.090432
# 3    0.517166  0.580938 -0.623623 -0.077731
# 4   -0.404962  0.373615  0.017960 -2.222403
# ..        ...       ...       ...       ...
# 495 -0.964836 -1.186450 -0.933296 -0.450081
# 496  0.985652 -0.692038 -0.141020  0.795576
# 497 -0.325201  0.200993  1.507935 -0.539887
# 498  1.944524 -1.426465 -0.360959  0.305695
# 499  0.426080  0.962170  0.099994  1.125589
#
# [500 rows x 4 columns]

# %%
_ = pd.plotting.scatter_matrix(df, figsize = (16, 16), alpha = 1, diagonal = 'kde')

# %%
s = abs(s)
s
# Out:
# 0       13.008430
# 1        8.155961
# 2        9.503509
# 3        9.540992
# 4       11.290433
#           ...
# 1995    34.411981
# 1996    26.051535
# 1997    27.999937
# 1998    32.997666
# 1999    32.328036
# Length: 2000, dtype: float64

# %%
s.plot(kind = 'pie')
# Out:
# <Axes: >

# %%
n =np.array([1,2,3,4,5])

# %%
n[0]
# Out:
# np.int64(1)

# %%
n[np.array([0,1,0,1,2,3])]
# Out:
# array([1, 2, 1, 2, 3, 4])

# %%
make = np.array([True, False, True, False, True])
make
# Out:
# array([ True, False,  True, False,  True])

# %%
n[make]
# Out:
# array([1, 3, 5])

# %%
make = np.array([True, False, True, False,True])
make
# Out:
# array([ True, False,  True, False,  True])

# %%
n
# Out:
# array([1, 2, 3, 4, 5])

# %%
n[make]
# Out:
# array([1, 3, 5])

# %%
n2 = np.array([[1,2,3], [4,5,6]])
n2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
mask1 = np.array([True, False])
n2[mask1]
# Out:
# array([[1, 2, 3]])

# %%
mask2 = np.array([[True,False, True], [False, True, False]])
n2[mask2]
# Out:
# array([1, 3, 5])

# %%
n2[mask2] = 8

# %%
n2
# Out:
# array([[8, 2, 8],
#        [4, 8, 6]])

# %%
df = DataFrame(data = np.random.randint(0, 10, size = (4,5)))
df
# Out:
#    0  1  2  3  4
# 0  1  9  2  1  2
# 1  9  5  6  2  6
# 2  0  9  9  0  2
# 3  8  4  7  5  7

# %%
df.loc[0,0]
# Out:
# np.int32(1)

# %%
df.loc[[0,0,1,1,2,2,3], [0,1,2,3,1,2,3]]
# Out:
#    0  1  2  3  1  2  3
# 0  1  9  2  1  9  2  1
# 0  1  9  2  1  9  2  1
# 1  9  5  6  2  5  6  2
# 1  9  5  6  2  5  6  2
# 2  0  9  9  0  9  9  0
# 2  0  9  9  0  9  9  0
# 3  8  4  7  5  4  7  5

# %%
s = Series(data = [True, False, True, False])
s
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df.loc[s]
# Out:
#    0  1  2  3  4
# 0  1  9  2  1  2
# 2  0  9  9  0  2

# %%
s
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s.index = list('abcd')

# %%
s
# Out:
# a     True
# b    False
# c     True
# d    False
# dtype: bool

# %%
df
# Out:
#    0  1  2  3  4
# 0  1  9  2  1  2
# 1  9  5  6  2  6
# 2  0  9  9  0  2
# 3  8  4  7  5  7

# %%
df.loc[s]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df.loc[s]
#
# File D:\venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File D:\venv\Lib\site-packages\pandas\core\indexing.py:1413, in _LocIndexer._getitem_axis(self, key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
# -> 1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#    1416     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# ...
