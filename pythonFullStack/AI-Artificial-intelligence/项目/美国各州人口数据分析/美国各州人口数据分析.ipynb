# %% [markdown]
# ## 美国各州人口数据分析

# %%
# unique() 去重函数
s = Series(['Tom','Lucy','Tom','dancer','Lucy'])

# %%
s.unique()
# Out:
# array(['Tom', 'Lucy', 'dancer'], dtype=object)

# %%
# ndarray也有去重函数
n = np.array([1, 2, 1, 3, 2, 4, 5])
np.unique(n)
# Out:
# array([1, 2, 3, 4, 5])

# %%
n = DataFrame({'name':['Tom','Lucy','Tom','dancer','Lucy'],'age':[12,13,12,11,15]})
n
# Out:
#      name  age
# 0     Tom   12
# 1    Lucy   13
# 2     Tom   12
# 3  dancer   11
# 4    Lucy   15

# %%
n.dtypes
# Out:
# name    object
# age      int64
# dtype: object

# %%
n.query("name=='Lucy' & age > 14")
# Out:
#    name  age
# 4  Lucy   15

# %%
# query 条件查询函数
n.query("name == 'Lucy' & age>14")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-302f942d5e82> in <module>()
#       1 # query 条件查询函数
# ----> 2 n.query("name == 'Lucy' & age>14")
#
# NameError: name 'n' is not defined

# %% [markdown]
# 首先导入文件，并查看数据样本

# %%
abb = pd.read_csv('./state-abbrevs.csv')
abb.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
pop = pd.read_csv('./state-population.csv')
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
areas = pd.read_csv('./state-areas.csv')
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %% [markdown]
# 合并pop与abbrevs两个DataFrame，分别依据state/region列和abbreviation列来合并。
#
# 为了保留所有信息，使用外合并。

# %%
abb_pop = abb.merge(pop, left_on='abbreviation', right_on='state/region', how='outer')

# %% [markdown]
# 去除abbreviation的那一列（axis=1）

# %%
# 另一种写法:abb_pop.drop(labels='abbreviation', axis=1, inplace=True)

# %%
abb_pop.drop(columns='abbreviation', inplace=True)

# %%
abb_pop.head()
# Out:
#      state state/region     ages  year  population
# 0  Alabama           AL  under18  2012   1117489.0
# 1  Alabama           AL    total  2012   4817528.0
# 2  Alabama           AL  under18  2010   1130966.0
# 3  Alabama           AL    total  2010   4785570.0
# 4  Alabama           AL  under18  2011   1125763.0

# %% [markdown]
# 查看存在缺失数据的列。
#
# 使用.isnull().any()，只有某一列存在一个缺失数据，就会显示True。

# %%
abb_pop.isnull().any(axis=0)
# Out:
# state            True
# state/region    False
# ages            False
# year            False
# population       True
# dtype: bool

# %%
abb_pop.isnull().any()
# Out:
# state            True
# state/region    False
# ages            False
# year            False
# population       True
# dtype: bool

# %%
# info也可以查看缺失数据
abb_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2544 entries, 0 to 2543
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         2448 non-null   object
#  1   state/region  2544 non-null   object
#  2   ages          2544 non-null   object
#  3   year          2544 non-null   int64
#  4   population    2524 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 119.2+ KB

# %% [markdown]
# 查看缺失数据

# %%
# 重点来了. 
# dataframe中有一种条件写法. 可以去过滤dataframe.
cond = abb_pop.isnull().any(axis=1)
cond
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2539     True
# 2540     True
# 2541     True
# 2542     True
# 2543     True
# Length: 2544, dtype: bool

# %%
# 根据条件去把缺失数据显示出来
temp = abb_pop.loc[cond].copy()
temp
# Out:
#      state state/region     ages  year   population
# 2448   NaN           PR  under18  1990          NaN
# 2449   NaN           PR    total  1990          NaN
# 2450   NaN           PR    total  1991          NaN
# 2451   NaN           PR  under18  1991          NaN
# 2452   NaN           PR    total  1993          NaN
# ...    ...          ...      ...   ...          ...
# 2539   NaN          USA    total  2010  309326295.0
# 2540   NaN          USA  under18  2011   73902222.0
# 2541   NaN          USA    total  2011  311582564.0
# 2542   NaN          USA  under18  2012   73708179.0
# 2543   NaN          USA    total  2012  313873685.0
#
# [96 rows x 5 columns]

# %% [markdown]
# 根据数据是否缺失情况显示数据，如果缺失为True，那么显示

# %% [markdown]
# 找到有哪些state/region使得state的值为NaN，使用unique()查看非重复值

# %%
temp['state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %% [markdown]
# 为找到的这些state/region的state项补上正确的值，从而去除掉state这一列的所有NaN！
#
# 记住这样清除缺失数据NaN的方法！

# %%
# 缺失数据处理的基本思路: 1. 能删则删, 不能删则填. 2. 尽量填的合理. 
# 先把所有state/region=PR的数据找出来, 然后把state填成波多黎各的全称. 
cond = temp['state/region'] == 'PR'
cond
# Out:
# 2448     True
# 2449     True
# 2450     True
# 2451     True
# 2452     True
#         ...
# 2539    False
# 2540    False
# 2541    False
# 2542    False
# 2543    False
# Name: state/region, Length: 96, dtype: bool

# %%
# 链式索引
temp.loc[cond]['state'] = 'Puerto Rico'
# Out:
# G:\venv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# 使用链式索引, 赋值没成功. 
# 链式索引, 是一个固有问题, 会引起无法预测的结果, unpredictable results.
temp.loc[cond]
# Out:
#      state state/region     ages  year  population
# 2448   NaN           PR  under18  1990         NaN
# 2449   NaN           PR    total  1990         NaN
# 2450   NaN           PR    total  1991         NaN
# 2451   NaN           PR  under18  1991         NaN
# 2452   NaN           PR    total  1993         NaN
# 2453   NaN           PR  under18  1993         NaN
# 2454   NaN           PR  under18  1992         NaN
# 2455   NaN           PR    total  1992         NaN
# 2456   NaN           PR  under18  1994         NaN
# 2457   NaN           PR    total  1994         NaN
# 2458   NaN           PR    total  1995         NaN
# 2459   NaN           PR  under18  1995         NaN
# 2460   NaN           PR  under18  1996         NaN
# 2461   NaN           PR    total  1996         NaN
# 2462   NaN           PR  under18  1998         NaN
# 2463   NaN           PR    total  1998         NaN
# 2464   NaN           PR    total  1997         NaN
# 2465   NaN           PR  under18  1997         NaN
# 2466   NaN           PR    total  1999         NaN
# 2467   NaN           PR  under18  1999         NaN
# 2468   NaN           PR    total  2000   3810605.0
# 2469   NaN           PR  under18  2000   1089063.0
# 2470   NaN           PR    total  2001   3818774.0
# 2471   NaN           PR  under18  2001   1077566.0
# 2472   NaN           PR    total  2002   3823701.0
# 2473   NaN           PR  under18  2002   1065051.0
# 2474   NaN           PR    total  2004   3826878.0
# 2475   NaN           PR  under18  2004   1035919.0
# 2476   NaN           PR    total  2003   3826095.0
# 2477   NaN           PR  under18  2003   1050615.0
# 2478   NaN           PR    total  2005   3821362.0
# 2479   NaN           PR  under18  2005   1019447.0
# 2480   NaN           PR    total  2006   3805214.0
# 2481   NaN           PR  under18  2006    998543.0
# 2482   NaN           PR    total  2007   3782995.0
# 2483   NaN           PR  under18  2007    973613.0
# 2484   NaN           PR    total  2008   3760866.0
# 2485   NaN           PR  under18  2008    945705.0
# 2486   NaN           PR  under18  2013    814068.0
# 2487   NaN           PR    total  2013   3615086.0
# 2488   NaN           PR    total  2009   3740410.0
# 2489   NaN           PR  under18  2009    920794.0
# 2490   NaN           PR    total  2010   3721208.0
# 2491   NaN           PR  under18  2010    896945.0
# 2492   NaN           PR  under18  2011    869327.0
# 2493   NaN           PR    total  2011   3686580.0
# 2494   NaN           PR  under18  2012    841740.0
# 2495   NaN           PR    total  2012   3651545.0

# %%
# 千万不要用链式索引, 应该使用官方推荐写法. 先对行操作, 然后再对列操作. 
temp.loc[cond, 'state'] = 'Puerto Rico'

# %%
# 赋值成功. 
temp.loc[cond]
# Out:
#             state state/region     ages  year  population
# 2448  Puerto Rico           PR  under18  1990         NaN
# 2449  Puerto Rico           PR    total  1990         NaN
# 2450  Puerto Rico           PR    total  1991         NaN
# 2451  Puerto Rico           PR  under18  1991         NaN
# 2452  Puerto Rico           PR    total  1993         NaN
# 2453  Puerto Rico           PR  under18  1993         NaN
# 2454  Puerto Rico           PR  under18  1992         NaN
# 2455  Puerto Rico           PR    total  1992         NaN
# 2456  Puerto Rico           PR  under18  1994         NaN
# 2457  Puerto Rico           PR    total  1994         NaN
# 2458  Puerto Rico           PR    total  1995         NaN
# 2459  Puerto Rico           PR  under18  1995         NaN
# 2460  Puerto Rico           PR  under18  1996         NaN
# 2461  Puerto Rico           PR    total  1996         NaN
# 2462  Puerto Rico           PR  under18  1998         NaN
# 2463  Puerto Rico           PR    total  1998         NaN
# 2464  Puerto Rico           PR    total  1997         NaN
# 2465  Puerto Rico           PR  under18  1997         NaN
# 2466  Puerto Rico           PR    total  1999         NaN
# 2467  Puerto Rico           PR  under18  1999         NaN
# 2468  Puerto Rico           PR    total  2000   3810605.0
# 2469  Puerto Rico           PR  under18  2000   1089063.0
# 2470  Puerto Rico           PR    total  2001   3818774.0
# 2471  Puerto Rico           PR  under18  2001   1077566.0
# 2472  Puerto Rico           PR    total  2002   3823701.0
# 2473  Puerto Rico           PR  under18  2002   1065051.0
# 2474  Puerto Rico           PR    total  2004   3826878.0
# 2475  Puerto Rico           PR  under18  2004   1035919.0
# 2476  Puerto Rico           PR    total  2003   3826095.0
# 2477  Puerto Rico           PR  under18  2003   1050615.0
# 2478  Puerto Rico           PR    total  2005   3821362.0
# 2479  Puerto Rico           PR  under18  2005   1019447.0
# 2480  Puerto Rico           PR    total  2006   3805214.0
# 2481  Puerto Rico           PR  under18  2006    998543.0
# 2482  Puerto Rico           PR    total  2007   3782995.0
# 2483  Puerto Rico           PR  under18  2007    973613.0
# 2484  Puerto Rico           PR    total  2008   3760866.0
# 2485  Puerto Rico           PR  under18  2008    945705.0
# 2486  Puerto Rico           PR  under18  2013    814068.0
# 2487  Puerto Rico           PR    total  2013   3615086.0
# 2488  Puerto Rico           PR    total  2009   3740410.0
# 2489  Puerto Rico           PR  under18  2009    920794.0
# 2490  Puerto Rico           PR    total  2010   3721208.0
# 2491  Puerto Rico           PR  under18  2010    896945.0
# 2492  Puerto Rico           PR  under18  2011    869327.0
# 2493  Puerto Rico           PR    total  2011   3686580.0
# 2494  Puerto Rico           PR  under18  2012    841740.0
# 2495  Puerto Rico           PR    total  2012   3651545.0

# %%
cond = temp['state/region'] == 'USA'
temp.loc[cond]
# Out:
#      state state/region     ages  year   population
# 2496   NaN          USA  under18  1990   64218512.0
# 2497   NaN          USA    total  1990  249622814.0
# 2498   NaN          USA    total  1991  252980942.0
# 2499   NaN          USA  under18  1991   65313018.0
# 2500   NaN          USA  under18  1992   66509177.0
# 2501   NaN          USA    total  1992  256514231.0
# 2502   NaN          USA    total  1993  259918595.0
# 2503   NaN          USA  under18  1993   67594938.0
# 2504   NaN          USA  under18  1994   68640936.0
# 2505   NaN          USA    total  1994  263125826.0
# 2506   NaN          USA  under18  1995   69473140.0
# 2507   NaN          USA  under18  1996   70233512.0
# 2508   NaN          USA    total  1995  266278403.0
# 2509   NaN          USA    total  1996  269394291.0
# 2510   NaN          USA    total  1997  272646932.0
# 2511   NaN          USA  under18  1997   70920738.0
# 2512   NaN          USA  under18  1998   71431406.0
# 2513   NaN          USA    total  1998  275854116.0
# 2514   NaN          USA  under18  1999   71946051.0
# 2515   NaN          USA    total  2000  282162411.0
# 2516   NaN          USA  under18  2000   72376189.0
# 2517   NaN          USA    total  1999  279040181.0
# 2518   NaN          USA    total  2001  284968955.0
# 2519   NaN          USA  under18  2001   72671175.0
# 2520   NaN          USA    total  2002  287625193.0
# 2521   NaN          USA  under18  2002   72936457.0
# 2522   NaN          USA    total  2003  290107933.0
# 2523   NaN          USA  under18  2003   73100758.0
# 2524   NaN          USA    total  2004  292805298.0
# 2525   NaN          USA  under18  2004   73297735.0
# 2526   NaN          USA    total  2005  295516599.0
# 2527   NaN          USA  under18  2005   73523669.0
# 2528   NaN          USA    total  2006  298379912.0
# 2529   NaN          USA  under18  2006   73757714.0
# 2530   NaN          USA    total  2007  301231207.0
# 2531   NaN          USA  under18  2007   74019405.0
# 2532   NaN          USA    total  2008  304093966.0
# 2533   NaN          USA  under18  2008   74104602.0
# 2534   NaN          USA  under18  2013   73585872.0
# 2535   NaN          USA    total  2013  316128839.0
# 2536   NaN          USA    total  2009  306771529.0
# 2537   NaN          USA  under18  2009   74134167.0
# 2538   NaN          USA  under18  2010   74119556.0
# 2539   NaN          USA    total  2010  309326295.0
# 2540   NaN          USA  under18  2011   73902222.0
# 2541   NaN          USA    total  2011  311582564.0
# 2542   NaN          USA  under18  2012   73708179.0
# 2543   NaN          USA    total  2012  313873685.0

# %%
temp.loc[cond, 'state'] = 'United State of America'
temp.loc[cond]
# Out:
#                         state state/region     ages  year   population
# 2496  United State of America          USA  under18  1990   64218512.0
# 2497  United State of America          USA    total  1990  249622814.0
# 2498  United State of America          USA    total  1991  252980942.0
# 2499  United State of America          USA  under18  1991   65313018.0
# 2500  United State of America          USA  under18  1992   66509177.0
# 2501  United State of America          USA    total  1992  256514231.0
# 2502  United State of America          USA    total  1993  259918595.0
# 2503  United State of America          USA  under18  1993   67594938.0
# 2504  United State of America          USA  under18  1994   68640936.0
# 2505  United State of America          USA    total  1994  263125826.0
# 2506  United State of America          USA  under18  1995   69473140.0
# 2507  United State of America          USA  under18  1996   70233512.0
# 2508  United State of America          USA    total  1995  266278403.0
# 2509  United State of America          USA    total  1996  269394291.0
# 2510  United State of America          USA    total  1997  272646932.0
# 2511  United State of America          USA  under18  1997   70920738.0
# 2512  United State of America          USA  under18  1998   71431406.0
# 2513  United State of America          USA    total  1998  275854116.0
# 2514  United State of America          USA  under18  1999   71946051.0
# 2515  United State of America          USA    total  2000  282162411.0
# 2516  United State of America          USA  under18  2000   72376189.0
# 2517  United State of America          USA    total  1999  279040181.0
# 2518  United State of America          USA    total  2001  284968955.0
# 2519  United State of America          USA  under18  2001   72671175.0
# 2520  United State of America          USA    total  2002  287625193.0
# 2521  United State of America          USA  under18  2002   72936457.0
# 2522  United State of America          USA    total  2003  290107933.0
# 2523  United State of America          USA  under18  2003   73100758.0
# 2524  United State of America          USA    total  2004  292805298.0
# 2525  United State of America          USA  under18  2004   73297735.0
# 2526  United State of America          USA    total  2005  295516599.0
# 2527  United State of America          USA  under18  2005   73523669.0
# 2528  United State of America          USA    total  2006  298379912.0
# 2529  United State of America          USA  under18  2006   73757714.0
# 2530  United State of America          USA    total  2007  301231207.0
# 2531  United State of America          USA  under18  2007   74019405.0
# 2532  United State of America          USA    total  2008  304093966.0
# 2533  United State of America          USA  under18  2008   74104602.0
# 2534  United State of America          USA  under18  2013   73585872.0
# 2535  United State of America          USA    total  2013  316128839.0
# 2536  United State of America          USA    total  2009  306771529.0
# 2537  United State of America          USA  under18  2009   74134167.0
# 2538  United State of America          USA  under18  2010   74119556.0
# 2539  United State of America          USA    total  2010  309326295.0
# 2540  United State of America          USA  under18  2011   73902222.0
# 2541  United State of America          USA    total  2011  311582564.0
# 2542  United State of America          USA  under18  2012   73708179.0
# 2543  United State of America          USA    total  2012  313873685.0

# %%
cond = abb_pop.isnull().any(axis=1)
abb_pop.loc[cond] = temp

# %%
abb_pop.loc[cond]
# Out:
#                         state state/region     ages  year   population
# 2448              Puerto Rico           PR  under18  1990          NaN
# 2449              Puerto Rico           PR    total  1990          NaN
# 2450              Puerto Rico           PR    total  1991          NaN
# 2451              Puerto Rico           PR  under18  1991          NaN
# 2452              Puerto Rico           PR    total  1993          NaN
# ...                       ...          ...      ...   ...          ...
# 2539  United State of America          USA    total  2010  309326295.0
# 2540  United State of America          USA  under18  2011   73902222.0
# 2541  United State of America          USA    total  2011  311582564.0
# 2542  United State of America          USA  under18  2012   73708179.0
# 2543  United State of America          USA    total  2012  313873685.0
#
# [96 rows x 5 columns]

# %% [markdown]
# 合并各州面积数据areas，使用左合并。
#
# 思考一下为什么使用外合并？

# %%
abb_pop.head()
# Out:
#      state state/region     ages  year  population
# 0  Alabama           AL  under18  2012   1117489.0
# 1  Alabama           AL    total  2012   4817528.0
# 2  Alabama           AL  under18  2010   1130966.0
# 3  Alabama           AL    total  2010   4785570.0
# 4  Alabama           AL  under18  2011   1125763.0

# %%
areas.head()
# Out:
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707

# %%
abb_pop_area = abb_pop.merge(areas, how='outer')
abb_pop_area.head()
# Out:
#      state state/region     ages  year  population  area (sq. mi)
# 0  Alabama           AL  under18  2012   1117489.0        52423.0
# 1  Alabama           AL    total  2012   4817528.0        52423.0
# 2  Alabama           AL  under18  2010   1130966.0        52423.0
# 3  Alabama           AL    total  2010   4785570.0        52423.0
# 4  Alabama           AL  under18  2011   1125763.0        52423.0

# %% [markdown]
# 继续寻找存在缺失数据的列

# %%
abb_pop_area.isnull().any()
# Out:
# state            False
# state/region     False
# ages             False
# year             False
# population        True
# area (sq. mi)     True
# dtype: bool

# %% [markdown]
# 我们会发现area(sq.mi)这一列有缺失数据，为了找出是哪一行，我们需要找出是哪个state没有数据

# %%
cond = abb_pop_area.isnull().any(axis=1)
abb_pop_area.loc[cond]
# Out:
#                         state state/region     ages  year   population  \
# 2448              Puerto Rico           PR  under18  1990          NaN
# 2449              Puerto Rico           PR    total  1990          NaN
# 2450              Puerto Rico           PR    total  1991          NaN
# 2451              Puerto Rico           PR  under18  1991          NaN
# 2452              Puerto Rico           PR    total  1993          NaN
# ...                       ...          ...      ...   ...          ...
# 2539  United State of America          USA    total  2010  309326295.0
# 2540  United State of America          USA  under18  2011   73902222.0
# 2541  United State of America          USA    total  2011  311582564.0
# 2542  United State of America          USA  under18  2012   73708179.0
# 2543  United State of America          USA    total  2012  313873685.0
#
#       area (sq. mi)
# 2448         3515.0
# 2449         3515.0
# 2450         3515.0
# 2451         3515.0
# 2452         3515.0
# ...             ...
# 2539            NaN
# 2540            NaN
# 2541            NaN
# 2542            NaN
# 2543            NaN
#
# [68 rows x 6 columns]

# %%
abb_pop_area.loc[cond, 'state'].unique()
# Out:
# array(['Puerto Rico', 'United State of America'], dtype=object)

# %%
temp = abb_pop_area.loc[cond].copy()
temp
# Out:
#                         state state/region     ages  year   population  \
# 2448              Puerto Rico           PR  under18  1990          NaN
# 2449              Puerto Rico           PR    total  1990          NaN
# 2450              Puerto Rico           PR    total  1991          NaN
# 2451              Puerto Rico           PR  under18  1991          NaN
# 2452              Puerto Rico           PR    total  1993          NaN
# ...                       ...          ...      ...   ...          ...
# 2539  United State of America          USA    total  2010  309326295.0
# 2540  United State of America          USA  under18  2011   73902222.0
# 2541  United State of America          USA    total  2011  311582564.0
# 2542  United State of America          USA  under18  2012   73708179.0
# 2543  United State of America          USA    total  2012  313873685.0
#
#       area (sq. mi)
# 2448         3515.0
# 2449         3515.0
# 2450         3515.0
# 2451         3515.0
# 2452         3515.0
# ...             ...
# 2539            NaN
# 2540            NaN
# 2541            NaN
# 2542            NaN
# 2543            NaN
#
# [68 rows x 6 columns]

# %%
# 缺了波多黎各1990到1999的人口数据, 但是我们要分析的是2010的人口数据, 所以缺失数据可以删除. 
temp.loc[temp['state'] == 'Puerto Rico']
# Out:
#             state state/region     ages  year  population  area (sq. mi)
# 2448  Puerto Rico           PR  under18  1990         NaN         3515.0
# 2449  Puerto Rico           PR    total  1990         NaN         3515.0
# 2450  Puerto Rico           PR    total  1991         NaN         3515.0
# 2451  Puerto Rico           PR  under18  1991         NaN         3515.0
# 2452  Puerto Rico           PR    total  1993         NaN         3515.0
# 2453  Puerto Rico           PR  under18  1993         NaN         3515.0
# 2454  Puerto Rico           PR  under18  1992         NaN         3515.0
# 2455  Puerto Rico           PR    total  1992         NaN         3515.0
# 2456  Puerto Rico           PR  under18  1994         NaN         3515.0
# 2457  Puerto Rico           PR    total  1994         NaN         3515.0
# 2458  Puerto Rico           PR    total  1995         NaN         3515.0
# 2459  Puerto Rico           PR  under18  1995         NaN         3515.0
# 2460  Puerto Rico           PR  under18  1996         NaN         3515.0
# 2461  Puerto Rico           PR    total  1996         NaN         3515.0
# 2462  Puerto Rico           PR  under18  1998         NaN         3515.0
# 2463  Puerto Rico           PR    total  1998         NaN         3515.0
# 2464  Puerto Rico           PR    total  1997         NaN         3515.0
# 2465  Puerto Rico           PR  under18  1997         NaN         3515.0
# 2466  Puerto Rico           PR    total  1999         NaN         3515.0
# 2467  Puerto Rico           PR  under18  1999         NaN         3515.0

# %%
# 缺失了全美的面积数据, 但是我们要分析的是各州的人口密度, 所以也可以删
temp.loc[temp['state'] == 'United State of America']
# Out:
#                         state state/region     ages  year   population  \
# 2496  United State of America          USA  under18  1990   64218512.0
# 2497  United State of America          USA    total  1990  249622814.0
# 2498  United State of America          USA    total  1991  252980942.0
# 2499  United State of America          USA  under18  1991   65313018.0
# 2500  United State of America          USA  under18  1992   66509177.0
# 2501  United State of America          USA    total  1992  256514231.0
# 2502  United State of America          USA    total  1993  259918595.0
# 2503  United State of America          USA  under18  1993   67594938.0
# 2504  United State of America          USA  under18  1994   68640936.0
# 2505  United State of America          USA    total  1994  263125826.0
# 2506  United State of America          USA  under18  1995   69473140.0
# 2507  United State of America          USA  under18  1996   70233512.0
# 2508  United State of America          USA    total  1995  266278403.0
# 2509  United State of America          USA    total  1996  269394291.0
# 2510  United State of America          USA    total  1997  272646932.0
# 2511  United State of America          USA  under18  1997   70920738.0
# 2512  United State of America          USA  under18  1998   71431406.0
# 2513  United State of America          USA    total  1998  275854116.0
# 2514  United State of America          USA  under18  1999   71946051.0
# 2515  United State of America          USA    total  2000  282162411.0
# 2516  United State of America          USA  under18  2000   72376189.0
# 2517  United State of America          USA    total  1999  279040181.0
# 2518  United State of America          USA    total  2001  284968955.0
# 2519  United State of America          USA  under18  2001   72671175.0
# 2520  United State of America          USA    total  2002  287625193.0
# 2521  United State of America          USA  under18  2002   72936457.0
# 2522  United State of America          USA    total  2003  290107933.0
# 2523  United State of America          USA  under18  2003   73100758.0
# 2524  United State of America          USA    total  2004  292805298.0
# 2525  United State of America          USA  under18  2004   73297735.0
# 2526  United State of America          USA    total  2005  295516599.0
# 2527  United State of America          USA  under18  2005   73523669.0
# 2528  United State of America          USA    total  2006  298379912.0
# 2529  United State of America          USA  under18  2006   73757714.0
# 2530  United State of America          USA    total  2007  301231207.0
# 2531  United State of America          USA  under18  2007   74019405.0
# 2532  United State of America          USA    total  2008  304093966.0
# 2533  United State of America          USA  under18  2008   74104602.0
# 2534  United State of America          USA  under18  2013   73585872.0
# 2535  United State of America          USA    total  2013  316128839.0
# 2536  United State of America          USA    total  2009  306771529.0
# 2537  United State of America          USA  under18  2009   74134167.0
# 2538  United State of America          USA  under18  2010   74119556.0
# 2539  United State of America          USA    total  2010  309326295.0
# 2540  United State of America          USA  under18  2011   73902222.0
# 2541  United State of America          USA    total  2011  311582564.0
# 2542  United State of America          USA  under18  2012   73708179.0
# 2543  United State of America          USA    total  2012  313873685.0
#
#       area (sq. mi)
# 2496            NaN
# 2497            NaN
# 2498            NaN
# 2499            NaN
# 2500            NaN
# 2501            NaN
# 2502            NaN
# 2503            NaN
# 2504            NaN
# 2505            NaN
# 2506            NaN
# 2507            NaN
# 2508            NaN
# 2509            NaN
# 2510            NaN
# 2511            NaN
# 2512            NaN
# 2513            NaN
# 2514            NaN
# 2515            NaN
# 2516            NaN
# 2517            NaN
# 2518            NaN
# 2519            NaN
# 2520            NaN
# 2521            NaN
# 2522            NaN
# 2523            NaN
# 2524            NaN
# 2525            NaN
# 2526            NaN
# 2527            NaN
# 2528            NaN
# 2529            NaN
# 2530            NaN
# 2531            NaN
# 2532            NaN
# 2533            NaN
# 2534            NaN
# 2535            NaN
# 2536            NaN
# 2537            NaN
# 2538            NaN
# 2539            NaN
# 2540            NaN
# 2541            NaN
# 2542            NaN
# 2543            NaN

# %% [markdown]
# 去除含有缺失数据的行

# %%
abb_pop_area.dropna(axis=0, inplace=True)

# %% [markdown]
# 查看数据是否缺失

# %%
abb_pop_area.isnull().any()
# Out:
# state            False
# state/region     False
# ages             False
# year             False
# population       False
# area (sq. mi)    False
# dtype: bool

# %%
abb_pop_area.head()
# Out:
#      state state/region     ages  year  population  area (sq. mi)
# 0  Alabama           AL  under18  2012   1117489.0        52423.0
# 1  Alabama           AL    total  2012   4817528.0        52423.0
# 2  Alabama           AL  under18  2010   1130966.0        52423.0
# 3  Alabama           AL    total  2010   4785570.0        52423.0
# 4  Alabama           AL  under18  2011   1125763.0        52423.0

# %%
abb_pop_area.dtypes
# Out:
# state             object
# state/region      object
# ages              object
# year               int64
# population       float64
# area (sq. mi)    float64
# dtype: object

# %% [markdown]
# 找出2010年的全民人口数据,df.query(查询语句)

# %%
result = abb_pop_area.query('ages == "total" & year==2010')

# %% [markdown]
# 对查询结果进行处理，以state列作为新的行索引:set_index

# %%
result.head()
# Out:
#           state state/region   ages  year  population  area (sq. mi)
# 3       Alabama           AL  total  2010   4785570.0        52423.0
# 91       Alaska           AK  total  2010    713868.0       656425.0
# 101     Arizona           AZ  total  2010   6408790.0       114006.0
# 189    Arkansas           AR  total  2010   2922280.0        53182.0
# 197  California           CA  total  2010  37333601.0       163707.0

# %%
result.set_index(keys='state', inplace=True)
result.head()
# Out:
#            state/region   ages  year  population  area (sq. mi)
# state
# Alabama              AL  total  2010   4785570.0        52423.0
# Alaska               AK  total  2010    713868.0       656425.0
# Arizona              AZ  total  2010   6408790.0       114006.0
# Arkansas             AR  total  2010   2922280.0        53182.0
# California           CA  total  2010  37333601.0       163707.0

# %% [markdown]
# 计算人口密度。注意是Series/Series，其结果还是一个Series。

# %%
# 人口密度 = 人口 / 面积
density = result['population'] / result['area (sq. mi)']

# %% [markdown]
# 排序，并找出人口密度最高的五个州sort_values()

# %%
# 默认是从小到大排序. 
density.sort_values(inplace=True)

# %%
# 人口密度最高的: District of Columbia 8898

# %%
density.tail()
# Out:
# state
# Connecticut              645.600649
# Rhode Island             681.339159
# New Jersey              1009.253268
# Puerto Rico             1058.665149
# District of Columbia    8898.897059
# dtype: float64

# %% [markdown]
# 找出人口密度最低的五个州

# %%
# Alaska 1.08
density.head()
# Out:
# state
# Alaska           1.087509
# Wyoming          5.768079
# Montana          6.736171
# North Dakota     9.537565
# South Dakota    10.583512
# dtype: float64
